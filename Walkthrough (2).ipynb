# %%
# import pandas, read in .csv file
import pandas
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# 13          14  Female   140  120  147   155.0    70.5     856472
# 14          15  Female    96  100   90   146.0    66.0     878897
# 15          16  Female    83   71   96   135.0    68.0     865363
# 16          17  Female   132  132  120   127.0    68.5     852244
# 17          18    Male   100   96  102   178.0    73.5     945088
# 18          19  Female   101  112   84   136.0    66.3     808020
# 19          20    Male    80   77   86   180.0    70.0     889083
# 20          21    Male    83   83   86     NaN     NaN     892420
# 21          22    Male    97  107   84   186.0    76.5     905940
# 22          23  Female   135  129  134   122.0    62.0     790619
# 23          24    Male   139  145  128   132.0    68.0     955003
# 24          25  Female    91   86  102   114.0    63.0     831772
# 25          26    Male   141  145  131   171.0    72.0     935494
# 26          27  Female    85   90   84   140.0    68.0     798612
# 27          28    Male   103   96  110   187.0    77.0    1062462
# 28          29  Female    77   83   72   106.0    63.0     793549
# 29          30  Female   130  126  124   159.0    66.5     866662
# 30          31  Female   133  126  132   127.0    62.5     857782
# 31          32    Male   144  145  137   191.0    67.0     949589
# 32          33    Male   103   96  110   192.0    75.5     997925
# 33          34    Male    90   96   86   181.0    69.0     879987
# 34          35  Female    83   90   81   143.0    66.5     834344
# 35          36  Female   133  129  128   153.0    66.5     948066
# 36          37    Male   140  150  124   144.0    70.5     949395
# 37          38  Female    88   86   94   139.0    64.5     893983
# 38          39    Male    81   90   74   148.0    74.0     930016
# 39          40    Male    89   91   89   179.0    75.5     935863

# %%
# Import Numpycreate arrays, designate t, sin_t, cos_t
import numpy as np
t = np.linspace(-6, 6, 20)
sin_t = np.sin(t)
cos_t = np.cos(t)

# %%
# Show table with designated t, sin,qnd cos values
pandas.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %%
# 40 rows and 8 columns
data.shape
# Out:
# (40, 8)

# %%
 # It has columns , show them
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %%
# Columns can be addressed by name (gender)
print(data['Gender'])
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
# Simpler selector
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# np.float64(109.45)

# %%
# group by gender and print mean values
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', np.float64(109.45))
# ('Male', np.float64(115.25))

# %%
# group by gender, and create columns with previous designations (FSIQ, VIQ, PIQ, Weight, Height
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %%
# Read data
data = pandas.read_csv('brain_size.csv', sep=';', na_values='.')

# Box plots of different columns for each gender
groupby_gender = data.groupby('Gender')
groupby_gender.boxplot(column=['FSIQ', 'VIQ', 'PIQ'])

from pandas.tools import plotting

# Scatter matrices for different columns
plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])

import matplotlib.pyplot as plt
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 8
#       5 groupby_gender = data.groupby('Gender')
#       6 groupby_gender.boxplot(column=['FSIQ', 'VIQ', 'PIQ'])
# ----> 8 from pandas.tools import plotting
#      10 # Scatter matrices for different columns
#      11 plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %%
# Tried a new import according to Google
from pandas.plotting import scatter_matrix

## new scatter matrix that
scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='MRI_Count', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='MRI_Count', ylabel='Height'>],
#        [<Axes: xlabel='Weight', ylabel='MRI_Count'>,
#         <Axes: xlabel='Height', ylabel='MRI_Count'>,
#         <Axes: xlabel='MRI_Count', ylabel='MRI_Count'>]], dtype=object)

# %%
# New scatter matrix that runs the same way as previous code
## scatter matrix with PIQ, VIQ, FSIQ
scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<Axes: xlabel='PIQ', ylabel='PIQ'>,
#         <Axes: xlabel='VIQ', ylabel='PIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='PIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='VIQ'>,
#         <Axes: xlabel='VIQ', ylabel='VIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='VIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='FSIQ'>,
#         <Axes: xlabel='VIQ', ylabel='FSIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='FSIQ'>]], dtype=object)

# %%
# Import stats
from scipy import stats

# %%
# Runs a 1 sample t-test from scipy.stats module testing previously imported data in the VIQ data frame
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# TtestResult(statistic=np.float64(30.08809997084933), pvalue=np.float64(1.3289196468727879e-28), df=np.int64(39))

# %%
# 2-sample t-test looking at males and females
female_viq = data[data['Gender'] == 'Female']['VIQ']
male_viq = data[data['Gender'] == 'Male']['VIQ']
stats.ttest_ind(female_viq, male_viq)
# Out:
# TtestResult(statistic=np.float64(-0.7726161723275012), pvalue=np.float64(0.44452876778583217), df=np.float64(38.0))

# %%
# Testing for significant difference
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(0.465637596380964), pvalue=np.float64(0.6427725009414841), df=np.float64(78.0))

# %%
# Paired samples t-test
stats.ttest_rel(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(1.7842019405859857), pvalue=np.float64(0.08217263818364236), df=np.int64(39))

# %%
# One sample t-test
stats.ttest_1samp(data['FSIQ'] - data['PIQ'], 0)
# Out:
# TtestResult(statistic=np.float64(1.7842019405859857), pvalue=np.float64(0.08217263818364236), df=np.int64(39))

# %%
# Relax assumptions of Gaussian errors
stats.wilcoxon(data['FSIQ'], data['PIQ'])
# Out:
# WilcoxonResult(statistic=np.float64(274.5), pvalue=np.float64(0.10659492713506856))

# %%
# Create a dataframe with a linear relationship between x and y 
import numpy as np
x = np.linspace(-5, 5, 20)
np.random.seed(1)
## normal distributed noise using random seed
y = -5 + 3*x + 4 * np.random.normal(size=x.shape)
# Create a data frame containing all the relevant variables
data = pandas.DataFrame({'x': x, 'y': y})

# %%
# Creaate a scatterplot and a simple linear regression

import matplotlib.pyplot as plt
plt.show()

x = np.linspace(-5, 5, 20)
## To get reproducable values, provide a seed value
np.random.seed(1)

y = -5 + 3*x + 4 * np.random.normal(size=x.shape)

## Plot the data
plt.figure(figsize=(5, 4))
plt.plot(x, y, 'o')

# %%
# Ordinary least squares (OLS) model and fit it
## Install statsmodels
# !pip install statsmodels
from statsmodels.formula.api import ols
model = ols("y ~ x", data).fit()
# Out:
# Requirement already satisfied: statsmodels in /srv/conda/envs/notebook/lib/python3.9/site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from statsmodels) (2.0.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from statsmodels) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.9/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.9/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
# Inspect statistics
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Fri, 12 Jul 2024   Prob (F-statistic):           8.56e-08
# Time:                        13:09:19   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# x              2.9369      0.341      8.604      0.000       2.220       3.654
# ==============================================================================
# Omnibus:                        0.100   Durbin-Watson:                   2.956
# Prob(Omnibus):                  0.951   Jarque-Bera (JB):                0.322
# Skew:                          -0.058   Prob(JB):                        0.851
# Kurtosis:                       2.390   Cond. No.                         3.03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Redesignate .csv to data
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")

# %%
# Force categorical
model = ols('VIQ ~ C(Gender)', data).fit()

# %%
# Log form table. indicate IQ as categorical value
data_fisq = pandas.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pandas.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pandas.concat((data_fisq, data_piq))
print(data_long)  
model = ols("iq ~ type", data_long).fit()
print(model.summary())
# Out:
#      iq  type
# 0   133  fsiq
# 1   140  fsiq
# 2   139  fsiq
# 3   133  fsiq
# 4   137  fsiq
# ..  ...   ...
# 35  128   piq
# 36  124   piq
# 37   94   piq
# 38   74   piq
# 39   89   piq
#
# [80 rows x 2 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     iq   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2168
# Date:                Fri, 12 Jul 2024   Prob (F-statistic):              0.643
# Time:                        13:09:23   Log-Likelihood:                -364.35
# No. Observations:                  80   AIC:                             732.7
# Df Residuals:                      78   BIC:                             737.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     113.4500      3.683     30.807      0.000     106.119     120.781
# type[T.piq]    -2.4250      5.208     -0.466      0.643     -12.793       7.943
# ==============================================================================
# Omnibus:                      164.598   Durbin-Watson:                   1.531
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.062
# Skew:                          -0.110   Prob(JB):                       0.0178
# Kurtosis:                       1.461   Cond. No.                         2.62
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# T-test and statistical test
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=np.float64(0.465637596380964), pvalue=np.float64(0.6427725009414841), df=np.float64(78.0))

# %%
#create 3D plots

# For 3d plots. This import is necessary to have 3D plotting below
from mpl_toolkits.mplot3d import Axes3D

# For statistics. Requires statsmodels 5.0 or more
from statsmodels.formula.api import ols
# Analysis of Variance (ANOVA) on linear models
from statsmodels.stats.anova import anova_lm

# %%
# Generate 3D plot data

## Generate a linearly spaced array of x values
x = np.linspace(-5, 5, 21)

## Generate a 2D grid
X, Y = np.meshgrid(x, x)

## To get reproducible values, provide a seed value
np.random.seed(1)

## Z is the elevation of 2D grid
Z = -5 + 3*X - 0.5*Y + 8 * np.random.normal(size=X.shape)

## Plot the data
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap=plt.cm.coolwarm, rstride=1, cstride=1)

## Set the view angle
ax.view_init(20, -120)

## Set the labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

## Show the plot
plt.show()

# %%
# Read CSV file, Fits OLS regression model, prints summary 
data = pandas.read_csv('iris.csv')
model = ols('sepal_width ~ name + petal_length', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Thu, 11 Jul 2024   Prob (F-statistic):           1.58e-20
# Time:                        23:30:14   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# name[T.versicolor]    -1.4821      0.181     -8.190      0.000      -1.840      -1.124
# name[T.virginica]     -1.6635      0.256     -6.502      0.000      -2.169      -1.158
# petal_length           0.2983      0.061      4.920      0.000       0.178       0.418
# ==============================================================================
# Omnibus:                        2.868   Durbin-Watson:                   1.753
# Prob(Omnibus):                  0.238   Jarque-Bera (JB):                2.885
# Skew:                          -0.082   Prob(JB):                        0.236
# Kurtosis:                       3.659   Cond. No.                         54.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Print model, no signiicant difference (greater than 0.05)
print(model.f_test([0, 1, -1, 0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Print model, no signiicant difference (greater than 0.05)
# ----> 2 print(model.f_test([0, 1, -1, 0]))
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/statsmodels/base/model.py:1784, in LikelihoodModelResults.f_test(self, r_matrix, cov_p, invcov)
#    1691 def f_test(self, r_matrix, cov_p=None, invcov=None):
#    1692     """
#    1693     Compute the F-test for a joint linear hypothesis.
#    1694
#    (...)
#    1782     <F test: F=array([[ 144.17976065]]), p=6.322026217355609e-08, df_denom=9, df_num=3>
#    1783     """
# -> 1784     res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True, scalar=True)
#    1785     return res
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/statsmodels/base/model.py:1864, in LikelihoodModelResults.wald_test(self, r_matrix, cov_p, invcov, use_f, df_constraints, scalar)
#    1862     names = self.model.data.cov_names
#    1863 params = self.params.ravel(order="F")
# -> 1864 LC = DesignInfo(names).linear_constraint(r_matrix)
#    1865 r_matrix, q_matrix = LC.coefs, LC.constants
#    1867 if (self.normalized_cov_params is None and cov_p is None and
#    1868         invcov is None and not hasattr(self, 'cov_params_default')):
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/patsy/design_info.py:536, in DesignInfo.linear_constraint(self, constraint_likes)
#     487 def linear_constraint(self, constraint_likes):
#     488     """Construct a linear constraint in matrix form from a (possibly
#     489     symbolic) description.
#     490
#    (...)
#     534       di.linear_constraint("x1 = x2 = 3")
#     535     """
# --> 536     return linear_constraint(constraint_likes, self.column_names)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/patsy/constraint.py:419, in linear_constraint(constraint_like, variable_names)
#     417 # assume a raw ndarray
#     418 coefs = np.asarray(constraint_like, dtype=float)
# --> 419 return LinearConstraint(variable_names, coefs)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/patsy/constraint.py:60, in LinearConstraint.__init__(self, variable_names, coefs, constants)
#      58     raise ValueError("constants is not (convertible to) a column matrix")
#      59 if self.coefs.ndim != 2 or self.coefs.shape[1] != len(variable_names):
# ---> 60     raise ValueError("wrong shape for coefs")
#      61 if self.coefs.shape[0] == 0:
#      62     raise ValueError("must have at least one row in constraint matrix")
#
# ValueError: wrong shape for coefs

# %%
# Show data
print(data)
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# 13          14  Female   140  120  147   155.0    70.5     856472
# 14          15  Female    96  100   90   146.0    66.0     878897
# 15          16  Female    83   71   96   135.0    68.0     865363
# 16          17  Female   132  132  120   127.0    68.5     852244
# 17          18    Male   100   96  102   178.0    73.5     945088
# 18          19  Female   101  112   84   136.0    66.3     808020
# 19          20    Male    80   77   86   180.0    70.0     889083
# 20          21    Male    83   83   86     NaN     NaN     892420
# 21          22    Male    97  107   84   186.0    76.5     905940
# 22          23  Female   135  129  134   122.0    62.0     790619
# 23          24    Male   139  145  128   132.0    68.0     955003
# 24          25  Female    91   86  102   114.0    63.0     831772
# 25          26    Male   141  145  131   171.0    72.0     935494
# 26          27  Female    85   90   84   140.0    68.0     798612
# 27          28    Male   103   96  110   187.0    77.0    1062462
# 28          29  Female    77   83   72   106.0    63.0     793549
# 29          30  Female   130  126  124   159.0    66.5     866662
# 30          31  Female   133  126  132   127.0    62.5     857782
# 31          32    Male   144  145  137   191.0    67.0     949589
# 32          33    Male   103   96  110   192.0    75.5     997925
# 33          34    Male    90   96   86   181.0    69.0     879987
# 34          35  Female    83   90   81   143.0    66.5     834344
# 35          36  Female   133  129  128   153.0    66.5     948066
# 36          37    Male   140  150  124   144.0    70.5     949395
# 37          38  Female    88   86   94   139.0    64.5     893983
# 38          39    Male    81   90   74   148.0    74.0     930016
# 39          40    Male    89   91   89   179.0    75.5     935863

# %%
# Install seaborn -- now in environment
## !pip install seaborn[stats]

# %%
# import urllib to bring in seaborn data
import urllib.request
urllib.request.urlretrieve('http://lib.stat.cmu.edu/datasets/CPS_85_Wages', 'wages.txt')
# Out:
# ('wages.txt', <http.client.HTTPMessage at 0x7f1aaa09cac0>)

# %%
# New import, regression lines for variables (from 3.1.4 problem with seaborn) data is still "iris.csv data but im not sure how to get seaborn data in instead... there is no .csv to downl;oad/
import pandas as pd
import seaborn as sns

## Load the dataset into a pandas DataFrame
column_names = ['EDUCATION', 'SOUTH', 'SEX', 'EXPERIENCE', 'UNION', 'WAGE', 'AGE', 'RACE', 'OCCUPATION', 'SECTOR', 'MARR']
data = pd.read_csv('wages.txt', skiprows=27, sep='\s+', names=column_names)

## Ensure columns are numeric and handle missing values
data['WAGE'] = pd.to_numeric(data['WAGE'], errors='coerce')
data['AGE'] = pd.to_numeric(data['AGE'], errors='coerce')
data['EDUCATION'] = pd.to_numeric(data['EDUCATION'], errors='coerce')

## Drop rows with missing values in the specified columns
data = data.dropna(subset=['WAGE', 'AGE', 'EDUCATION'])

## Create a pairplot
sns.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'], kind='reg')

# %%
# Plot categorical variables as the hue
sns.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg',diag_kind='hist', hue='SEX')  
# Show the plot
plt.show()

# %%
# Alternate way to make same two images mixing in more coding with additional help from ChatGPT, Google, and Walkthorugh

## Import data
import pandas
import os

if not os.path.exists('wages.txt'):
    # Download the file if it is not present
    urllib.urlretrieve('http://lib.stat.cmu.edu/datasets/CPS_85_Wages',
                       'wages.txt')

## Name the columns
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]

short_names = [n.split(':')[0] for n in names]

 
data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,
                       header=None, engine='python')
data.columns = short_names

## Log-transform the wages, because they typically are increased with multiplicative factors
import numpy as np
data['WAGE'] = np.log10(data['WAGE'])

# %%
# Make graphs of above code
import seaborn
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg',diag_kind='hist', hue='SEX')
plt.suptitle('Effect of gender: 1=Female, 0=Male')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg',diag_kind='hist', hue='RACE')
plt.suptitle('Effect of race: 1=Other, 2=Hispanic, 3=White')

seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg',diag_kind='hist', hue='UNION')
plt.suptitle('Effect of union: 1=Union member, 0=Not union member')
# Out:
# Text(0.5, 0.98, 'Effect of union: 1=Union member, 0=Not union member')

# %%
from matplotlib import pyplot as plt
plt.rcdefaults()

# %%
# Regression showing wage and education
sns.lmplot(y='WAGE', x='EDUCATION', data=data)

# %%
#graph both male and female together 
# WAGE: Wage (dollars per hour)
data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,
                       header=None, names=['education', 'gender', 'wage'],
                       usecols=[0, 2, 5],
                       )

# Convert genders to strings (this is particulary useful so that the
# statsmodels formulas detects that gender is a categorical variable)
import numpy as np
data['gender'] = np.choose(data.gender, ['male', 'female'])

# Log-transform the wages, because they typically are increased with
# multiplicative factors
data['wage'] = np.log10(data['wage'])

import seaborn

# Plot 2 linear fits for male and female.
sns.lmplot(y='wage', x='education', hue='gender', data=data)
# Out:
# /tmp/ipykernel_218/1040323782.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None,

# %%
import statsmodels.formula.api as smf
column_names = ['EDUCATION', 'SOUTH', 'SEX', 'EXPERIENCE', 'UNION', 'WAGE', 'AGE', 'RACE', 'OCCUPATION', 'SECTOR', 'MARR']
data = pd.read_csv('wages.txt', skiprows=27, sep='\s+', names=column_names)

# Ensure columns are numeric and handle missing values
data['WAGE'] = pd.to_numeric(data['WAGE'], errors='coerce')
data['AGE'] = pd.to_numeric(data['AGE'], errors='coerce')
data['EDUCATION'] = pd.to_numeric(data['EDUCATION'], errors='coerce')

# Drop rows with missing values in the specified columns
data = data.dropna(subset=['WAGE', 'AGE', 'EDUCATION'])

# Fit the OLS model
result = smf.ols(formula='WAGE ~ EDUCATION + SEX + EDUCATION * SEX', data=data).fit()
print(result.summary())

sns.lmplot(y='WAGE', x='EDUCATION', hue='GENDER', data=data)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   WAGE   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.186
# Method:                 Least Squares   F-statistic:                     41.50
# Date:                Fri, 12 Jul 2024   Prob (F-statistic):           4.24e-24
# Time:                        13:11:03   Log-Likelihood:                -1575.0
# No. Observations:                 534   AIC:                             3158.
# Df Residuals:                     530   BIC:                             3175.
# Df Model:                           3
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              1.1046      1.314      0.841      0.401      -1.476       3.685
# SEX[T.1]              -4.3704      2.085     -2.096      0.037      -8.466      -0.274
# EDUCATION              0.6831      0.099      6.918      0.000       0.489       0.877
# EDUCATION:SEX[T.1]     0.1725      0.157      1.098      0.273      -0.136       0.481
# ==============================================================================
# Omnibus:                      208.151   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1278.081
# Skew:                           1.587   Prob(JB):                    2.94e-278
# Kurtosis:                       9.883   Cond. No.                         170.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 17
#      14 result = smf.ols(formula='WAGE ~ EDUCATION + SEX + EDUCATION * SEX', data=data).fit()
#      15 print(result.summary())
# ---> 17 sns.lmplot(y='WAGE', x='EDUCATION', hue='GENDER', data=data)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/seaborn/regression.py:611, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     609 need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     610 cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 611 data = data[cols]
#     613 # Initialize the grid
#     614 facets = FacetGrid(
#     615     data, row=row, col=col, hue=hue,
#     616     palette=palette,
#    (...)
#     619     **facet_kws,
#     620 )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['GENDER'] not in index"
